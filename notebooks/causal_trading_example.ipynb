# %% [markdown]
# # Causal Trading Strategy Example
#
# This notebook demonstrates how to use the causal inference-based trading strategy to analyze and trade financial instruments.

# %%
# !pip3 install -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt
# !pip3 install numpy==1.21.0

import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from data.collector import FinancialDataCollector
from causal_trading.models.trading_strategy import CausalTradingStrategy
# Out:
# Requirement already satisfied: numpy>=1.21.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: yfinance>=0.2.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (0.2.50)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 4)) (1.5.2)
# Requirement already satisfied: statsmodels>=0.13.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 5)) (0.14.4)
# Requirement already satisfied: networkx>=2.6.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: dowhy>=0.8 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 7)) (0.8)
# Requirement already satisfied: econml>=0.14.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (0.15.1)
# Requirement already satisfied: matplotlib>=3.4.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 9)) (3.9.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 10)) (0.13.2)
# Requirement already satisfied: jupyter>=1.0.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: pytest>=6.2.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from -r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 12)) (8.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from pandas>=1.3.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from pandas>=1.3.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from pandas>=1.3.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: requests>=2.31 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (1.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from scikit-learn>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 4)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from scikit-learn>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from scikit-learn>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from statsmodels>=0.13.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from statsmodels>=0.13.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 5)) (24.2)
# Requirement already satisfied: sympy>=1.4 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from dowhy>=0.8->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 7)) (1.13.3)
# Requirement already satisfied: pydot>=1.4 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from dowhy>=0.8->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: sparse in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (0.15.4)
# Requirement already satisfied: shap<0.44.0,>=0.38.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (0.43.0)
# Requirement already satisfied: lightgbm in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 9)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 9)) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 9)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: notebook in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (7.2.2)
# Requirement already satisfied: jupyter-console in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (7.16.4)
# Requirement already satisfied: ipykernel in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (6.29.5)
# Requirement already satisfied: ipywidgets in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (8.1.5)
# Requirement already satisfied: jupyterlab in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (4.2.6)
# Requirement already satisfied: iniconfig in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from pytest>=6.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from pytest>=6.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 12)) (1.5.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (2.6)
# Requirement already satisfied: six>=1.9 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from html5lib>=1.1->yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: webencodings in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from html5lib>=1.1->yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from requests>=2.31->yfinance>=0.2.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 3)) (2024.8.30)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from shap<0.44.0,>=0.38.1->econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (4.67.0)
# Requirement already satisfied: slicer==0.0.7 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from shap<0.44.0,>=0.38.1->econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (0.0.7)
# Requirement already satisfied: numba in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from shap<0.44.0,>=0.38.1->econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (0.60.0)
# Requirement already satisfied: cloudpickle in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from shap<0.44.0,>=0.38.1->econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from sympy>=1.4->dowhy>=0.8->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: appnope in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.8.9)
# Requirement already satisfied: ipython>=7.23.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: psutil in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipywidgets->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipywidgets->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-console->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (3.0.48)
# Requirement already satisfied: pygments in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-console->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (75.6.0)
# Requirement already satisfied: bleach!=5.0.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: anyio in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.0.7)
# Requirement already satisfied: sniffio in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.14.0)
# Requirement already satisfied: decorator in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: stack-data in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.9.28)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.20.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from numba->shap<0.44.0,>=0.38.1->econml>=0.14.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 8)) (0.43.0)
# Requirement already satisfied: wcwidth in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.21.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: fqdn in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: uri-template in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.17.1)
# Requirement already satisfied: pycparser in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r /Users/sujal/CascadeProjects/causal_trading/requirements.txt (line 11)) (2.9.0.20241003)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting numpy==1.21.0
#   Downloading numpy-1.21.0.zip (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 37.7 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/commands/install.py", line 379, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#                             ^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_vendor/resolvelib/resolvers.py", line 397, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_vendor/resolvelib/resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_vendor/resolvelib/structs.py", line 156, in __bool__
#     return bool(self._sequence)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 174, in __bool__
#     return any(self)
#            ^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 162, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#                        ^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 53, in _iter_built
#     candidate = func()
#                 ^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 186, in _make_candidate_from_link
#     base: Optional[BaseCandidate] = self._make_base_candidate_from_link(
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 232, in _make_base_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#                                        ^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 303, in __init__
#     super().__init__(
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 158, in __init__
#     self.dist = self._prepare()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 235, in _prepare
#     dist = self._prepare_distribution()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 314, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/operations/prepare.py", line 527, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/operations/prepare.py", line 642, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/operations/prepare.py", line 72, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/distributions/sdist.py", line 56, in prepare_distribution_metadata
#     self._install_build_reqs(finder)
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/distributions/sdist.py", line 126, in _install_build_reqs
#     build_reqs = self._get_build_requires_wheel()
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/distributions/sdist.py", line 103, in _get_build_requires_wheel
#     return backend.get_requires_for_build_wheel()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_internal/utils/misc.py", line 706, in get_requires_for_build_wheel
#     return super().get_requires_for_build_wheel(config_settings=cs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_impl.py", line 166, in get_requires_for_build_wheel
#     return self._call_hook('get_requires_for_build_wheel', {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_impl.py", line 321, in _call_hook
#     raise BackendUnavailable(data.get('traceback', ''))
# pip._vendor.pyproject_hooks._impl.BackendUnavailable: Traceback (most recent call last):
#   File "/Users/sujal/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 77, in _build_backend
#     obj = import_module(mod_path)
#           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "/private/var/folders/46/853jx4m96z3f22x9djqcyqp80000gn/T/pip-build-env-x14nllxj/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 18, in <module>
#     from setuptools.extern.six import PY3, string_types
# ModuleNotFoundError: No module named 'setuptools.extern.six'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 13
#      10 import seaborn as sns
#      12 from data.collector import FinancialDataCollector
# ---> 13 from causal_trading.models.trading_strategy import CausalTradingStrategy
#
# File ~/CascadeProjects/causal_trading/notebooks/../src/causal_trading/models/trading_strategy.py:4
#       2 import pandas as pd
#       3 from typing import List, Dict, Optional
# ----> 4 from .causal_model import CausalInferenceModel
#       6 class CausalTradingStrategy:
#       7     """Trading strategy based on causal inference insights."""
#
# File ~/CascadeProjects/causal_trading/notebooks/../src/causal_trading/models/causal_model.py:7
#       5 from dowhy import CausalModel
#       6 from sklearn.preprocessing import StandardScaler
# ----> 7 from econml.dml import CausalForestDML, DML
#       8 from sklearn.linear_model import LassoCV
#       9 from sklearn.ensemble import RandomForestRegressor
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/dml/__init__.py:37
#       2 # Copyright (c) PyWhy contributors. All rights reserved.
#       3 # Licensed under the MIT License.
#       5 """Double Machine Learning. The method uses machine learning methods to identify the
#       6 part of the observed outcome and treatment that is not predictable by the controls X, W
#       7 (aka residual outcome and residual treatment).
#    (...)
#      34     ACM Conference on Learning Theory. `<https://arxiv.org/abs/1901.09036>`_
#      35 """
# ---> 37 from .dml import (DML, LinearDML, SparseLinearDML,
#      38                   KernelDML, NonParamDML)
#      39 from .causal_forest import CausalForestDML
#      41 __all__ = ["DML",
#      42            "LinearDML",
#      43            "SparseLinearDML",
#      44            "KernelDML",
#      45            "NonParamDML",
#      46            "CausalForestDML"]
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/dml/dml.py:18
#      15 from sklearn.utils import check_random_state
#      16 import copy
# ---> 18 from .._ortho_learner import _OrthoLearner
#      19 from ._rlearner import _RLearner
#      20 from .._cate_estimator import (DebiasedLassoCateEstimatorMixin,
#      21                                ForestModelFinalCateEstimatorMixin,
#      22                                LinearModelFinalCateEstimatorMixin,
#      23                                StatsModelsCateEstimatorMixin,
#      24                                LinearCateEstimator)
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/_ortho_learner.py:43
#      39 from sklearn.preprocessing import (FunctionTransformer, LabelEncoder,
#      40                                    OneHotEncoder)
#      41 from sklearn.utils import check_random_state
# ---> 43 from ._cate_estimator import (BaseCateEstimator, LinearCateEstimator,
#      44                               TreatmentExpansionMixin)
#      45 from .inference import BootstrapInference
#      46 from .utilities import (_deprecate_positional, check_input_arrays,
#      47                         cross_product, filter_none_kwargs, one_hot_encoder, strata_from_discrete_arrays,
#      48                         inverse_onehot, jacify_featurizer, ndim, reshape, shape, transpose)
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/_cate_estimator.py:12
#      10 from copy import deepcopy
#      11 from warnings import warn
# ---> 12 from .inference import BootstrapInference
#      13 from .utilities import (tensordot, ndim, reshape, shape, parse_final_model_params, get_feature_names_or_default,
#      14                         inverse_onehot, Summary, get_input_columns, check_input_arrays, jacify_featurizer)
#      15 from .inference import StatsModelsInference, StatsModelsInferenceDiscrete, LinearModelFinalInference, \
#      16     LinearModelFinalInferenceDiscrete, NormalInferenceResults, GenericSingleTreatmentModelFinalInference, \
#      17     GenericModelFinalInferenceDiscrete
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/inference/__init__.py:4
#       1 # Copyright (c) PyWhy contributors. All rights reserved.
#       2 # Licensed under the MIT License.
# ----> 4 from ._inference import (BootstrapInference, GenericModelFinalInference, GenericSingleTreatmentModelFinalInference,
#       5                          LinearModelFinalInference, StatsModelsInference, GenericModelFinalInferenceDiscrete,
#       6                          LinearModelFinalInferenceDiscrete, StatsModelsInferenceDiscrete,
#       7                          NormalInferenceResults, EmpiricalInferenceResults,
#       8                          PopulationSummaryResults)
#      10 __all__ = ["BootstrapInference",
#      11            "GenericModelFinalInference",
#      12            "GenericSingleTreatmentModelFinalInference",
#    (...)
#      19            "EmpiricalInferenceResults",
#      20            "PopulationSummaryResults"]
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/inference/_inference.py:15
#      12 from statsmodels.iolib.table import SimpleTable
#      14 from ._bootstrap import BootstrapEstimator
# ---> 15 from ..sklearn_extensions.linear_model import StatsModelsLinearRegression
#      16 from ..utilities import (Summary, _safe_norm_ppf, broadcast_unit_treatments,
#      17                          cross_product, inverse_onehot, ndim,
#      18                          parse_final_model_params, jacify_featurizer,
#      19                          reshape_treatmentwise_effects, shape, filter_none_kwargs)
#      21 """Options for performing inference in estimators."""
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/sklearn_extensions/linear_model.py:23
#      21 from collections.abc import Iterable
#      22 from scipy.stats import norm
# ---> 23 from ..utilities import ndim, shape, reshape, _safe_norm_ppf, check_input_arrays
#      24 from sklearn import clone
#      25 from sklearn.linear_model import LinearRegression, LassoCV, MultiTaskLassoCV, Lasso, MultiTaskLasso
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/econml/utilities.py:10
#       8 import scipy.sparse
#       9 import sklearn
# ---> 10 import sparse as sp
#      11 import itertools
#      12 import inspect
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/sparse/__init__.py:77
#      74 from numpy import power as pow
#      75 from numpy import right_shift as bitwise_right_shift
# ---> 77 from ._common import (
#      78     SparseArray,
#      79     abs,
#      80     all,
#      81     any,
#      82     asarray,
#      83     asnumpy,
#      84     astype,
#      85     broadcast_arrays,
#      86     broadcast_to,
#      87     concat,
#      88     concatenate,
#      89     dot,
#      90     einsum,
#      91     empty,
#      92     empty_like,
#      93     equal,
#      94     eye,
#      95     full,
#      96     full_like,
#      97     isfinite,
#      98     isinf,
#      99     isnan,
#     100     matmul,
#     101     max,
#     102     mean,
#     103     min,
#     104     moveaxis,
#     105     nonzero,
#     106     ones,
#     107     ones_like,
#     108     outer,
#     109     pad,
#     110     permute_dims,
#     111     prod,
#     112     reshape,
#     113     round,
#     114     squeeze,
#     115     stack,
#     116     std,
#     117     sum,
#     118     tensordot,
#     119     zeros,
#     120     zeros_like,
#     121 )
#     122 from ._compressed import GCXS
#     123 from ._coo import COO, as_coo
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/sparse/_common.py:8
#       5 from itertools import chain
#       6 from operator import index, mul
# ----> 8 import numba
#       9 from numba import literal_unroll
#      11 import numpy as np
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/numba/__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
#      56             raise ImportError(msg)
# ---> 59 _ensure_critical_deps()
#      60 # END DO NOT MOVE
#      61 # ---------------------- WARNING WARNING WARNING ----------------------------
#      64 from ._version import get_versions
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/numba/__init__.py:45, in _ensure_critical_deps()
#      42 if numpy_version > (2, 0):
#      43     msg = (f"Numba needs NumPy 2.0 or less. Got NumPy "
#      44            f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 45     raise ImportError(msg)
#      47 try:
#      48     import scipy
#
# ImportError: Numba needs NumPy 2.0 or less. Got NumPy 2.1.

# %% [markdown]
# ## 1. Data Collection
#
# First, let's collect historical data for some popular tech stocks.

# %%
# Initialize data collector
collector = FinancialDataCollector()

# Define symbols
symbols = ['AAPL', 'GOOGL', 'MSFT', 'AMZN']

# Fetch data
data = collector.fetch_stock_data(
    symbols=symbols,
    start_date='2020-01-01'
)

# Calculate returns and technical indicators
data = collector.calculate_returns(data)
data = collector.add_technical_indicators(data)

data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 14
#       8 data = collector.fetch_stock_data(
#       9     symbols=symbols,
#      10     start_date='2020-01-01'
#      11 )
#      13 # Calculate returns and technical indicators
# ---> 14 data = collector.calculate_returns(data)
#      15 data = collector.add_technical_indicators(data)
#      17 data.head()
#
# File ~/CascadeProjects/causal_trading/notebooks/../src/data/collector.py:59, in FinancialDataCollector.calculate_returns(self, df)
#      50 """Calculate various return metrics.
#      51
#      52 Args:
#    (...)
#      56     DataFrame with additional return columns
#      57 """
#      58 df['Daily_Return'] = df.groupby('Symbol')['Close'].pct_change()
# ---> 59 df['Log_Return'] = df.groupby('Symbol')['Close'].apply(lambda x: np.log(x/x.shift(1)))
#      61 # Calculate rolling metrics
#      62 df['Rolling_Volatility'] = df.groupby('Symbol')['Daily_Return'].rolling(window=20).std()
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:230, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     224 @Appender(
#     225     _apply_docs["template"].format(
#     226         input="series", examples=_apply_docs["series_examples"]
#     227     )
#     228 )
#     229 def apply(self, func, *args, **kwargs) -> Series:
# --> 230     return super().apply(func, *args, **kwargs)
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1824, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1822 with option_context("mode.chained_assignment", None):
#    1823     try:
# -> 1824         result = self._python_apply_general(f, self._selected_obj)
#    1825         if (
#    1826             not isinstance(self.obj, Series)
#    1827             and self._selection is None
#    1828             and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1829         ):
#    1830             warnings.warn(
#    1831                 message=_apply_groupings_depr.format(
#    1832                     type(self).__name__, "apply"
#    (...)
#    1835                 stacklevel=find_stack_level(),
#    1836             )
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)
#    1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
#    1860     Apply function f in python space
#    1861
#    (...)
#    1883         data after applying f
#    1884     """
# -> 1885     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886     if not_indexed_same is None:
#    1887         not_indexed_same = mutated
#
# File ~/CascadeProjects/causal_trading/venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# File ~/CascadeProjects/causal_trading/notebooks/../src/data/collector.py:59, in FinancialDataCollector.calculate_returns.<locals>.<lambda>(x)
#      50 """Calculate various return metrics.
#      51
#      52 Args:
#    (...)
#      56     DataFrame with additional return columns
#      57 """
#      58 df['Daily_Return'] = df.groupby('Symbol')['Close'].pct_change()
# ---> 59 df['Log_Return'] = df.groupby('Symbol')['Close'].apply(lambda x: np.log(x/x.shift(1)))
#      61 # Calculate rolling metrics
#      62 df['Rolling_Volatility'] = df.groupby('Symbol')['Daily_Return'].rolling(window=20).std()
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## 2. Initialize Trading Strategy
#
# Now, let's set up our causal trading strategy.

# %%
# Define features for causal analysis
features = ['Volume_Ratio', 'Rolling_Volatility', 'RSI']

# Initialize strategy
strategy = CausalTradingStrategy(
    symbols=symbols,
    lookback_period=252,  # One year of trading days
    confidence_threshold=0.95
)

# %% [markdown]
# ## 3. Generate Trading Signals
#
# Let's analyze the data and generate trading signals.

# %%
# Get trading signals
signals = strategy.identify_trading_signals(
    data=data,
    features=features
)

print("Trading Signals:")
for symbol, signal in signals.items():
    print(f"{symbol}: {signal:>6.2f}")

# %% [markdown]
# ## 4. Backtest Strategy
#
# Let's evaluate the strategy's performance through backtesting.

# %%
# Run backtest
backtest_results = strategy.backtest(
    data=data,
    features=features,
    initial_capital=1000000
)

# Generate performance report
performance = strategy.generate_trading_report(backtest_results)

print("\nPerformance Metrics:")
for metric, value in performance.items():
    print(f"{metric}: {value:>10.2%}")

# %% [markdown]
# ## 5. Visualize Results
#
# Let's create some visualizations to better understand the strategy's performance.

# %%
# Plot portfolio value over time
plt.figure(figsize=(12, 6))
plt.plot(backtest_results['Date'], backtest_results['Portfolio_Value'])
plt.title('Portfolio Value Over Time')
plt.xlabel('Date')
plt.ylabel('Portfolio Value ($)')
plt.grid(True)
plt.show()

# Plot daily returns distribution
plt.figure(figsize=(10, 6))
sns.histplot(backtest_results['Daily_Return'], bins=50)
plt.title('Distribution of Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
